# %%
#Bài tập for 2: Game21
import random
r = random.Random()
current_number = 0
# current_player = r.randint(0,1)
# if current_player == 0:
#     current_player = "human"
# else:
#     current_player = "computer"
current_player = "human"
while current_number <= 21:
#     print(f"Current number is {current_number}")
    if current_player == "human":
        player_choice = int(input("Player's turn. Input number between 1 and 3:"))
        while player_choice == 1 or player_choice == 2 or player_choice == 3:
            current_number += player_choice
            print(f"Player's turn. Current number is {current_number}")
            if current_number == 21:
                print("Player's turn. Current number is 21. You lose!")
                break
            else:
                current_player = "computer"
            break
        else:
            print("You must input number between 1 and 3. Please input again!")    
    if current_player == "computer": 
        print("Computer's turn")
        computer_choice = r.randint(1,3)
        print(f"Computer's choice is {computer_choice}")
        current_number += computer_choice
        print(f"Computer's turn. Current number is {current_number}")
        if current_number == 21:
            print("Computer's turn. Current number is 21. You win!")
            break
        else:
            current_player = "human"
            
    
    
    
    
#     if current_player == 0:
#         current_player = "human"
#     else:
#         current_player = "computer"
#     while current_number <= 21:
#         if current_player == "human":
#             print(f"{current_player}'s turn'")
#             player_choice = int(input("Input your number:"))
#             while player_choice == 1 or player_choice == 2 or player_choice == 3:
#                 current_number += player_choice
#                 if current_number == 21:
#                     print("Current number is 21. You lose!")
#                 else:
#                     current_player = "computer"
#         if current_player == "computer":
#             print(f"{current_player}'s turn'")
#             player_choice = r.randint(1,3)
#             if current_number == 21:
#                 print("Current number is 21. You win!")
#             else:
#                 current_player = "human"
# Out:
# Player's turn. Input number between 1 and 3:1
# Player's turn. Current number is 1
# Computer's turn
# Computer's choice is 3
# Computer's turn. Current number is 4
# Player's turn. Input number between 1 and 3:3
# Player's turn. Current number is 7
# Computer's turn
# Computer's choice is 3
# Computer's turn. Current number is 10
# Player's turn. Input number between 1 and 3:2
# Player's turn. Current number is 12
# Computer's turn
# Computer's choice is 3
# Computer's turn. Current number is 15
# Player's turn. Input number between 1 and 3:3
# Player's turn. Current number is 18
# Computer's turn
# Computer's choice is 3
# Computer's turn. Current number is 21
# Computer's turn. Current number is 21. You win!
